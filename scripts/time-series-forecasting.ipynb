# %% [markdown]
# # Time Series Machine Learning with XGBoost
# - Dataset: Ice cream 🍦 sales
# - Our **forecasting Horizon** will be 1 year (52 weeks) out into the future in which we will predict ice cream sales.
# - Model(s): Linear Regression, XGBoost, or ARIMA

# %%
import pandas as pd
import numpy as np
import altair as alt
import datetime as dt

# Model
import xgboost as xgb
import sklearn
from sklearn.model_selection import TimeSeriesSplit 
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Import data

# %%
# Read in data
df = pd.read_excel(r'/home/jacquelinezhangg/workspace-jz/personal-projects/forecasting-ice-cream-sales/data/ice_cream_sales.xlsx')

# %%
df.head()
# Out:
#                      Region         Periods       Item       $  Units
# 0  Albany/Schenectady/Troy   1 w/e 12/09/17  ICE CREAM  490.64  199.0
# 1  Albany/Schenectady/Troy   1 w/e 12/16/17  ICE CREAM  416.82  170.0
# 2  Albany/Schenectady/Troy   1 w/e 12/23/17  ICE CREAM  465.42  192.0
# 3  Albany/Schenectady/Troy   1 w/e 12/30/17  ICE CREAM  331.47  135.0
# 4  Albany/Schenectady/Troy   1 w/e 01/06/18  ICE CREAM  459.42  190.0

# %% [markdown]
# ## Exploratory Data Analysis and Data Processing

# %% [markdown]
# Some data processing on the Date column

# %%
df['Periods'] = df['Periods'].str.split(' ', expand=True)[2]
df['Periods'] = pd.to_datetime(df['Periods'])

# %% [markdown]
# EDA
# - Null values
# - Duplicates
# - Visualization of the trend and seasonality
# - Possible outliers

# %%
df.isnull().sum() # No null values
# Out:
# Region     0
# Periods    0
# Item       0
# $          0
# Units      0
# dtype: int64

# %%
df[df.duplicated(subset=['Region', 'Periods', 'Item'])] # No duplicates
# Out:
# Empty DataFrame
# Columns: [Region, Periods, Item, $, Units]
# Index: []

# %%
def multiple_line_plot(df, title='Chart', date='date', width=800, height=400):
    """Transforms the dataframe by grouping by month and year and aggregating the numerical values. Then it plots that dataframe to see the monthly values.

    Args:
        df (pandas DataFrame): Data
        title (str, optional): Title of your plot. Defaults to 'Chart'.
        date (str, optional): Date column in your data. Defaults to 'date'.
        width (int, optional): Width of your plot. Defaults to 800.

    Returns:
        altair Chart: Plot of the monthly revenue
    """
    df[date] = pd.to_datetime(df[date])
    sum_of_revenue = df.groupby(by=df[date].dt.strftime('%Y %B')).sum(numeric_only=True).reset_index(drop=False)
    sum_of_revenue[date] = pd.to_datetime(sum_of_revenue[date]).sort_values().reset_index(drop=True)
    sum_of_revenue = sum_of_revenue.rename(columns={date: 'MONTH'})
    df_melt = sum_of_revenue.melt(id_vars='MONTH', var_name='VARIABLE', value_name='VALUE')

    return alt.Chart(df_melt).mark_line(
        color='lightblue',
        point=alt.OverlayMarkDef(color='darkblue'),
        width=30).encode(
            x=alt.X('MONTH:O', timeUnit='yearmonth', axis=alt.Axis(labelAngle=-90)),
            y='VALUE',
            color='VARIABLE'
            ).properties(title=title, width=width, height=height).interactive()

multiple_line_plot(df, title='Monthly Ice Cream Sales', date='Periods', width=800, height=400)
# Out:
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# Seems like there are seasonal fluctuations where Ice Cream sales are highest in the warmer times of the year and dip during season transitions

# %% [markdown]
# Outlier Detection

# %% [markdown]
# There are multiple stores, so we will aggregate all stores up to weekly-time-level data

# %%
# Transform to datetime dtype
df['Periods'] = pd.to_datetime(df['Periods'])

# Group by the dates being transformed in month and year
sum_of_revenue = df.groupby(by=df['Periods']).sum(numeric_only=True).reset_index(drop=False)

# Convert the date into datetime again to sort in order
sum_of_revenue['Periods'] = pd.to_datetime(sum_of_revenue['Periods']).sort_values().reset_index(drop=True)
sum_of_revenue = sum_of_revenue.rename(columns={'Periods': 'Date'})

# %%
# Create a copy to be able to manipulate the data
data_raw = sum_of_revenue.copy()
data_raw.head()
# Out:
#         Date          $      Units
# 0 2017-12-09  72767.839  31271.712
# 1 2017-12-16  61041.047  25734.947
# 2 2017-12-23  60838.874  25668.437
# 3 2017-12-30  51489.301  21898.136
# 4 2018-01-06  59647.489  25215.005

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### Create features extracted from the time
# - Month, Quarter, Year, Day of Year, and Seasons
# - Data is at a weekly level

# %%
def create_features(data):
    """Creation of features (month, quarter, year, day of year, and season) using the date

    Args:
        data (pandas DataFrame): Time series data

    Returns:
        pandas DataFrame: Time series data with new features
    """
    data = data.copy()

    data['month'] = data['Date'].dt.month
    data['quarter'] = data['Date'].dt.quarter
    data['year'] = data['Date'].dt.year
    data['day_of_year'] = data['Date'].dt.day_of_year
    
    conditions = [
        (data['Date'].dt.month.isin(np.arange(3,6))),
        (data['Date'].dt.month.isin(np.arange(6,9))),
        (data['Date'].dt.month.isin(np.arange(9,12))),
        (data['Date'].dt.month.isin(np.append(np.arange(1,3), 12)))
    ]
    # 1 is Spring, 2 is Summer, 3 is Fall, and 4 is Winter
    choices = [1, 2, 3, 4]
    data['seasons'] = np.select(conditions, choices)
    return data

data = create_features(data_raw)

# %% [markdown]
# #### Lag
# - Lag Features: the model will look back into the past and use it as a new feature to feed into the model
#     - For example, if you like to forecast the sales in period `t`, you can use the sales of the previous month `t-1` as a feature
#
# Visualizations
# - Partial autocorrelation plot (correlogram): This will tell me the correlation of a lag along with all of the previous lags. Plotting the partial autocorrelation will help me choose which lag features to use.
#     - Trying different lag lengths:
#         - Day: looks ok but dips after 9 days
#         - Month: does not look the best
#         - Year: has good correlation throughout!
# - Lag plot: Plot the unit and $ metrics against their lags to show the relationship. If it is a strong relationship, this shows their serial dependence.

# %%
def partial_autocorrelation_plot(data):
    """Plot autocorrelation out 3 lags (yearly) with a threshold of 0.3 (0.3 means they are loosely correlated)

    Args:
        data (pandas DataFrame): Data

    Returns:
        altair Chart: Autocorrelation chart of dollar sales and units 
    """
    temp = data.copy()
    for lag in np.arange(1, 10):
        # Multiply 4 to represent months
        # Multiply by 52 to represent a year
        temp[f'lag_Units_{lag}'] = temp['Units'].shift(periods=52*lag)
        temp[f'lag_$_{lag}'] = temp['$'].shift(periods=52*lag)

    # Calculate correlation
    temp = temp.corr(numeric_only=True).head(2)[['lag_Units_1', 'lag_$_1', 'lag_Units_2', 'lag_$_2',
        'lag_Units_3', 'lag_$_3', 'lag_Units_4', 'lag_$_4', 'lag_Units_5',
        'lag_$_5', 'lag_Units_6', 'lag_$_6', 'lag_Units_7', 'lag_$_7',
        'lag_Units_8', 'lag_$_8', 'lag_Units_9', 'lag_$_9']]

    # Split up by revenue and units
    temp_corr_rev = temp[temp.columns[temp.columns.str.contains('$', regex=False)]].drop('Units', axis=0)
    temp_corr_units = temp[temp.columns[temp.columns.str.contains('Units', regex=False)]].drop('Units', axis=0)
    
    # Altair plot
    rev_chart = alt.Chart(temp_corr_rev.melt()).mark_bar().encode(
        x='variable',
        y='value'
    )
    units_chart = alt.Chart(temp_corr_units.melt()).mark_bar().encode(
        x='variable',
        y='value'
    )
    line = alt.Chart(pd.DataFrame({'y': [0.3]})).mark_rule(color='red').encode(y='y')
    return alt.vconcat(rev_chart + line, units_chart + line)

partial_autocorrelation_plot(data)
# Out:
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %% [markdown]
# In the figure above, the lags start dropping in correlation the farther we go out. Therefore we should pick the closest 3

# %%
def lag_plots(data, lag_num):
    """Plots a correlation chart between the units/$ metrics to their lags for how ever many lags specified

    Args:
        data (pandas DataFrame): Data
        lag_num (int): Number of lags. Level is yearly.

    Returns:
        altair Chart: Correlation lag plot
    """
    temp = data.copy()
    charts = []
    for lag in np.arange(1, lag_num+1):
        # Multiply by 52 to represent a year
        temp['lag_Units'] = temp['Units'].shift(periods=52*lag)
        temp['lag_$'] = temp['$'].shift(periods=52*lag)

        chart1 = alt.Chart(temp).mark_point().encode(x='lag_Units', y='Units')
        chart2 = alt.Chart(temp).mark_point(color = 'green').encode(x='lag_$', y='$')

        charts.append((
            chart1 + 
            chart1.transform_regression('lag_Units', 'Units').mark_line(color='light blue') + 
            chart2 + 
            chart2.transform_regression('lag_$', '$').mark_line(color='green')
            ).properties(title=f'Lag: {lag}'))

    # * means packaging arguments. In a function call, the * symbol can be used to pass a list of arguments as separate positional arguments
    # Also shared the x-axis among all charts
    return alt.vconcat(*charts).resolve_scale(
        x='shared'
    )

# Looking at correlation with 3 lag features
lag_plots(data, 3)
# Out:
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
def lag(data, lag_num):
    """Create yearly lag features

    Args:
        data (pandas DataFrame): Data
        lag_num (int): Number of lag features you want to create. Level is yearly.

    Returns:
        pandas DataFrame: Data with added lag features
    """
    data = data.copy()
    for lag in np.arange(1, lag_num+1):
        # Multiply by 52 to represent a year
        data[f'lag_Units_{lag}'] = data['Units'].shift(periods=52*lag)
        data[f'lag_$_{lag}'] = data['$'].shift(periods=52*lag)
    return data

# Create lag features and picking 3 lags
data = lag(data, 3)

# %% [markdown]
# Set the Date as the index for easier manipulation

# %%
# Set Date as the index
data = data.set_index('Date')
data.head()
# Out:
#                     $      Units  month  quarter  year  day_of_year  seasons  \
# Date
# 2017-12-09  72767.839  31271.712     12        4  2017          343        4
# 2017-12-16  61041.047  25734.947     12        4  2017          350        4
# 2017-12-23  60838.874  25668.437     12        4  2017          357        4
# 2017-12-30  51489.301  21898.136     12        4  2017          364        4
# 2018-01-06  59647.489  25215.005      1        1  2018            6        4
#
#             lag_Units_1  lag_$_1  lag_Units_2  lag_$_2  lag_Units_3  lag_$_3
# Date
# 2017-12-09          NaN      NaN          NaN      NaN          NaN      NaN
# 2017-12-16          NaN      NaN          NaN      NaN          NaN      NaN
# 2017-12-23          NaN      NaN          NaN      NaN          NaN      NaN
# 2017-12-30          NaN      NaN          NaN      NaN          NaN      NaN
# 2018-01-06          NaN      NaN          NaN      NaN          NaN      NaN

# %% [markdown]
# ## Visualize Feature and Target relationship
# Looking to see where features have a strong relationship with the $ and unit metrics

# %%
alt.data_transformers.disable_max_rows()
alt.Chart(data).mark_boxplot(extent='min-max').encode(
    x='month',
    y='$'
).properties(title='Relationship of $ and Month')
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_boxplot(extent='min-max').encode(
    x='quarter',
    y='$'
).properties(title='Relationship of $ and Quarter')
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_boxplot(extent='min-max').encode(
    x='seasons',
    y='$'
).properties(title='Relationship of $ and Seasons')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Split train and test data

# %%
# Finding the cutoff date for splitting up our dataset
testing = data.index.nunique()*0.2
training = data.index.nunique()*0.8
print('Cutoff point: ', data.index.max() - dt.timedelta(weeks=testing))

train = data[data.index < '2021-12-02'].copy()
test = data[data.index >= '2021-12-02'].copy()
# Out:
# Cutoff point:  2021-12-02 14:24:00

# %% [markdown]
# Split the train and test datasets into their own features and targets respectively

# %%
features = ['quarter', 'month', 'year', 'day_of_year', 'seasons', 'lag_Units_1', 'lag_$_1', 'lag_Units_2', 'lag_$_2', 'lag_Units_3', 'lag_$_3']
target = ['Units', '$']

X_train = train[features].copy()
y_train = train[target].copy()

X_test = test[features].copy()
y_test = test[target].copy()

# %% [markdown]
# ## Model Creation, Training, and Validation
# For XGBoost, we will use the regression model

# %%
# reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=30, learning_rate=0.02)

# After grid search:
reg = xgb.XGBRegressor(learning_rate=0.05, max_depth=2, n_estimators=180)
reg.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=5)
# Out:
# [0]	validation_0-rmse:756079.23618	validation_1-rmse:842936.22939
# [5]	validation_0-rmse:602476.15642	validation_1-rmse:685043.38442
# [10]	validation_0-rmse:486525.18642	validation_1-rmse:553650.60600
# [15]	validation_0-rmse:398853.53456	validation_1-rmse:451441.42187
# [20]	validation_0-rmse:331703.84772	validation_1-rmse:373525.82188
# [25]	validation_0-rmse:278847.63468	validation_1-rmse:315834.28253
# [30]	validation_0-rmse:239269.05424	validation_1-rmse:272926.76544
# [35]	validation_0-rmse:209363.39850	validation_1-rmse:238330.77120
# [40]	validation_0-rmse:188145.36521	validation_1-rmse:210567.47337
# [45]	validation_0-rmse:172728.81503	validation_1-rmse:193335.67633
# [50]	validation_0-rmse:161597.09491	validation_1-rmse:180415.49304
# [55]	validation_0-rmse:148928.30061	validation_1-rmse:166335.43709
# [60]	validation_0-rmse:139398.07495	validation_1-rmse:156536.42985
# [65]	validation_0-rmse:130913.51622	validation_1-rmse:150466.80536
# [70]	validation_0-rmse:124876.65024	validation_1-rmse:145287.49347
# [75]	validation_0-rmse:120212.29093	validation_1-rmse:141886.44000
# [80]	validation_0-rmse:116823.86359	validation_1-rmse:139572.13215
# [85]	validation_0-rmse:113955.27509	validation_1-rmse:142297.79994
# [90]	validation_0-rmse:111468.18564	validation_1-rmse:143649.88476
# [95]	validation_0-rmse:109488.30501	validation_1-rmse:146982.68918
# [100]	validation_0-rmse:107881.16389	validation_1-rmse:149293.17588
# [105]	validation_0-rmse:105743.47624	validation_1-rmse:149626.46418
# [110]	validation_0-rmse:103415.54841	validation_1-rmse:149360.46574
# [115]	validation_0-rmse:101810.02354	validation_1-rmse:150265.54040
# [120]	validation_0-rmse:99859.33900	validation_1-rmse:151053.03472
# [125]	validation_0-rmse:98437.11930	validation_1-rmse:151726.07742
# [130]	validation_0-rmse:96760.96908	validation_1-rmse:151653.80217
# [135]	validation_0-rmse:95179.85120	validation_1-rmse:151896.41403
# [140]	validation_0-rmse:93875.09316	validation_1-rmse:152340.55737
# [145]	validation_0-rmse:92382.65962	validation_1-rmse:152986.99799
# [150]	validation_0-rmse:90885.80551	validation_1-rmse:153310.18161
# [155]	validation_0-rmse:89692.97671	validation_1-rmse:154173.81648
# [160]	validation_0-rmse:88434.42952	validation_1-rmse:154841.99337
# [165]	validation_0-rmse:87125.88917	validation_1-rmse:155395.22508
# [170]	validation_0-rmse:86356.18276	validation_1-rmse:156062.41262
# [175]	validation_0-rmse:85451.47865	validation_1-rmse:156364.56443
# [179]	validation_0-rmse:84345.67240	validation_1-rmse:156200.49478
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=2, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=180, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %% [markdown]
# ## Training Model

# %% [markdown]
# GridSearch

# %%
# Fine Tune the model
from sklearn.model_selection import GridSearchCV

xgb_reg = xgb.XGBRegressor()

# Already tried {'degree': [3, 4, 5, 6], 'C': [1, 2, 3, 4, 5, 7, 8, 9, 10, 11]}
param_grid = [
    {
        'max_depth': range(2, 10),
        'n_estimators': range(60, 220, 40),
        'learning_rate': [0.1, 0.01, 0.05],
    }
]

# The higher the verbose number, the more text output describing the process
grid_search = GridSearchCV(xgb_reg, param_grid, cv=5, refit=True, verbose=3, scoring='neg_mean_squared_error', return_train_score=True)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=60;, score=(train=-4141969406.945, test=-19860593068.591) total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=60;, score=(train=-4820842360.670, test=-5778563153.657) total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=60;, score=(train=-4088907184.801, test=-14946130302.316) total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=60;, score=(train=-3860857543.655, test=-21197159099.574) total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=60;, score=(train=-4063908491.449, test=-8822278422.407) total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=(train=-2840070446.281, test=-19747002576.867) total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=(train=-3036087927.619, test=-8286344747.534) total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=(train=-2605542974.036, test=-13897927877.934) total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=(train=-2725249016.483, test=-16470346971.710) total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=100;, score=(train=-2526450837.196, test=-13021354597.119) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=140;, score=(train=-2186360231.853, test=-18687899974.829) total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=140;, score=(train=-2315282520.330, test=-9581126950.088) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=140;, score=(train=-1947940825.140, test=-14297948190.736) total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=140;, score=(train=-2263404136.897, test=-14951441285.143) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=140;, score=(train=-1883823272.064, test=-15153615683.559) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=2, n_estimators=180;, score=(train=-1772772319.227, test=-17802495463.308) total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=2, n_estimators=180;, score=(train=-1896202525.341, test=-10568045144.920) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=2, n_estimators=180;, score=(train=-1514256591.276, test=-15348760468.610) total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=2, n_estimators=180;, score=(train=-1923527650.187, test=-14214849965.949) total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=2, n_estimators=180;, score=(train=-1527056850.111, test=-16622305436.913) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=60;, score=(train=-1507894222.328, test=-18773038652.465) total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=60;, score=(train=-1803396522.224, test=-13377254267.204) total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=60;, score=(train=-1442838161.226, test=-17838120420.100) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=60;, score=(train=-1372153116.404, test=-16167919461.221) total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=60;, score=(train=-1316400597.453, test=-16509618027.880) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-663029613.317, test=-19557593908.555) total time=   1.1s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-941991658.664, test=-16012496828.720) total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-728185135.524, test=-19005658703.826) total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-663245865.611, test=-13190976399.924) total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=(train=-744387828.527, test=-18923252981.314) total time=   0.5s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=140;, score=(train=-430523610.315, test=-19406813988.232) total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=140;, score=(train=-528009648.827, test=-17444526256.538) total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=140;, score=(train=-478606762.495, test=-19488529113.063) total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=140;, score=(train=-398433179.623, test=-12693515752.464) total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=140;, score=(train=-481833306.296, test=-19445914865.661) total time=   1.4s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=(train=-288572471.206, test=-19538150994.881) total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=(train=-338102193.145, test=-17516356224.648) total time=   1.3s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=(train=-272413321.775, test=-20360322830.367) total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=(train=-278690519.539, test=-12790411438.391) total time=   3.9s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=180;, score=(train=-327513002.634, test=-19778657001.894) total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=60;, score=(train=-571969526.666, test=-19373411526.905) total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=60;, score=(train=-651938033.902, test=-17207640812.510) total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=60;, score=(train=-588809542.174, test=-14559757768.895) total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=60;, score=(train=-699776408.690, test=-14279644971.345) total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=60;, score=(train=-488924922.121, test=-17689486802.709) total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=-177499727.043, test=-20175962115.227) total time=   1.2s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=-257123825.034, test=-20007702502.705) total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=-174500955.507, test=-16913338821.157) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=-275098081.194, test=-12575484453.694) total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=-163298730.910, test=-19857516979.440) total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=140;, score=(train=-74085899.258, test=-20420464272.920) total time=   0.7s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=140;, score=(train=-122660995.819, test=-20619458002.428) total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=140;, score=(train=-85450871.165, test=-17347122950.301) total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=140;, score=(train=-151985908.197, test=-12594129450.821) total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=140;, score=(train=-78446986.512, test=-20295433260.020) total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=(train=-38898520.574, test=-20682914818.988) total time=   1.2s
# [CV 2/5] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=(train=-70668713.825, test=-20945090632.173) total time=   1.5s
# [CV 3/5] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=(train=-47325382.095, test=-17479737817.216) total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=(train=-81678331.016, test=-12646736655.398) total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_depth=4, n_estimators=180;, score=(train=-44060649.902, test=-20531722364.549) total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=60;, score=(train=-413602556.692, test=-18208422565.853) total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=60;, score=(train=-396256185.875, test=-23599983283.238) total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=60;, score=(train=-288216159.536, test=-12516399069.450) total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=60;, score=(train=-453452783.266, test=-13422690379.684) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=60;, score=(train=-321018403.929, test=-18876317026.881) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-123942533.020, test=-19503695625.308) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-96599213.025, test=-26852081828.410) total time=   1.5s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-80012765.434, test=-13019429742.347) total time=   1.2s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-160986040.315, test=-12373932296.961) total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=(train=-59026711.310, test=-20517874326.278) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=140;, score=(train=-55480515.879, test=-19952936845.993) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=140;, score=(train=-27718447.952, test=-27665286013.196) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=140;, score=(train=-27778606.427, test=-13107843589.773) total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=140;, score=(train=-37532524.605, test=-11338205583.816) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=140;, score=(train=-19080403.609, test=-20870615880.946) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=(train=-21892920.733, test=-20382123315.047) total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=(train=-10991553.231, test=-27891945987.390) total time=   1.3s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=(train=-14905327.460, test=-13221800512.990) total time=   2.3s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=(train=-14860705.491, test=-11229637484.441) total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=180;, score=(train=-8986760.425, test=-21014193294.493) total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=60;, score=(train=-233851302.554, test=-18891661254.314) total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=60;, score=(train=-205213187.982, test=-25281140913.466) total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=60;, score=(train=-204355943.790, test=-12102931717.068) total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=60;, score=(train=-278040143.930, test=-14047726382.015) total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=60;, score=(train=-170589584.576, test=-18824750951.127) total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=-36978760.662, test=-20403241658.421) total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=-27732583.577, test=-27042633845.815) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=-25405500.224, test=-12378963888.970) total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=-44053867.281, test=-12442079192.935) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=-30409561.380, test=-20496768539.555) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=140;, score=(train=-11412072.891, test=-20609240657.290) total time=   3.1s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=140;, score=(train=-8613239.028, test=-27672117819.424) total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=140;, score=(train=-7372285.034, test=-12494493515.873) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=140;, score=(train=-10991250.311, test=-12123529482.431) total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=140;, score=(train=-8559771.665, test=-20832366116.610) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=(train=-4095874.056, test=-20719961230.544) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=(train=-2374076.781, test=-28032992389.757) total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=(train=-2738092.813, test=-12502420904.192) total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=(train=-4602795.966, test=-12119347178.984) total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_depth=6, n_estimators=180;, score=(train=-3260999.874, test=-20969030145.323) total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=60;, score=(train=-127515299.385, test=-19315401030.145) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=60;, score=(train=-117306154.956, test=-26186561496.584) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=60;, score=(train=-137253838.839, test=-12308954789.662) total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=60;, score=(train=-183626636.800, test=-13160474050.564) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=60;, score=(train=-107133089.379, test=-18937689264.439) total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=(train=-9650522.153, test=-20643201907.703) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=(train=-9156125.954, test=-27882601475.728) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=(train=-8284394.952, test=-12451310732.649) total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=(train=-23105181.613, test=-11692077240.924) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=(train=-6522489.686, test=-20781957677.090) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=140;, score=(train=-1898870.957, test=-20783823528.276) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=140;, score=(train=-2200615.302, test=-28011834082.322) total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=140;, score=(train=-1911413.553, test=-12474819344.900) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=140;, score=(train=-6229239.754, test=-11484025669.003) total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=140;, score=(train=-885997.487, test=-21055241991.088) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=(train=-520698.227, test=-20838770295.464) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=(train=-567436.004, test=-28065695317.394) total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=(train=-597698.173, test=-12479973698.375) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=(train=-2044346.915, test=-11456548569.773) total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=180;, score=(train=-272392.987, test=-21086248528.545) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=60;, score=(train=-103347715.705, test=-19402470268.115) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=60;, score=(train=-92402167.108, test=-25767189886.468) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=60;, score=(train=-97944789.285, test=-12423021111.487) total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=60;, score=(train=-130129326.395, test=-12665143882.527) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=60;, score=(train=-97279681.519, test=-18902325764.925) total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=-3223007.269, test=-20701388688.124) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=-2440996.652, test=-26839375735.678) total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=-2780008.145, test=-12408367497.892) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=-9520674.828, test=-11273858187.685) total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=-3584133.253, test=-20796691083.194) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=140;, score=(train=-282549.477, test=-20832613202.754) total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=140;, score=(train=-315499.237, test=-27103329914.848) total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=140;, score=(train=-172657.331, test=-12403994518.983) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=140;, score=(train=-1608830.742, test=-11171194981.156) total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=140;, score=(train=-438763.425, test=-21046440050.840) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=(train=-60970.251, test=-20847110381.104) total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=(train=-81555.162, test=-27162932413.914) total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=(train=-37604.371, test=-12409371311.854) total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=(train=-417242.908, test=-11153156485.713) total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=8, n_estimators=180;, score=(train=-89896.552, test=-21083647265.005) total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=9, n_estimators=60;, score=(train=-89092491.674, test=-19466603078.008) total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=9, n_estimators=60;, score=(train=-82856680.516, test=-25687780071.341) total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=9, n_estimators=60;, score=(train=-85311479.850, test=-12378728719.919) total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=9, n_estimators=60;, score=(train=-101571058.285, test=-12825356191.966) total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=9, n_estimators=60;, score=(train=-81767270.072, test=-18917124632.318) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=(train=-1850474.007, test=-20702358087.997) total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=(train=-1385921.536, test=-26834352801.686) total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=(train=-1521973.733, test=-12336952723.375) total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=(train=-4522330.582, test=-11291607345.253) total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=(train=-1746959.797, test=-20834285518.958) total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=9, n_estimators=140;, score=(train=-106293.356, test=-20829245053.005) total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=9, n_estimators=140;, score=(train=-29400.192, test=-26962538756.133) total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=9, n_estimators=140;, score=(train=-36798.783, test=-12311990970.512) total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=9, n_estimators=140;, score=(train=-585304.658, test=-11185426257.477) total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=9, n_estimators=140;, score=(train=-54009.825, test=-21071399791.260) total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=9, n_estimators=180;, score=(train=-16368.677, test=-20846863830.401) total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=9, n_estimators=180;, score=(train=-1309.874, test=-26981059942.131) total time=   0.5s
# [CV 3/5] END learning_rate=0.1, max_depth=9, n_estimators=180;, score=(train=-2102.195, test=-12307451463.867) total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=9, n_estimators=180;, score=(train=-129836.242, test=-11175315552.964) total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=9, n_estimators=180;, score=(train=-4516.478, test=-21103240230.461) total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=60;, score=(train=-225860517610.108, test=-164905209000.024) total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=60;, score=(train=-234404372431.408, test=-189802229368.779) total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=60;, score=(train=-246488470279.969, test=-129077539855.306) total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=60;, score=(train=-205919081556.650, test=-378512552311.128) total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=60;, score=(train=-210095817053.347, test=-299871453172.757) total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=(train=-118670052887.491, test=-73656869622.896) total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=(train=-126364402341.286, test=-101457298571.539) total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=(train=-131260960111.872, test=-72422451909.933) total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=(train=-112664131445.642, test=-242254653949.879) total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=100;, score=(train=-115262416404.120, test=-160760498940.102) total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=140;, score=(train=-66352966158.412, test=-39687669531.746) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=140;, score=(train=-72908601283.166, test=-57678565991.339) total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=140;, score=(train=-74154116796.572, test=-46465357480.498) total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=140;, score=(train=-65649310608.485, test=-162404246828.367) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=140;, score=(train=-67348674684.424, test=-90390543700.019) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=2, n_estimators=180;, score=(train=-40402314952.161, test=-29059988423.188) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=2, n_estimators=180;, score=(train=-45410811243.465, test=-36509496227.681) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=2, n_estimators=180;, score=(train=-44707807468.824, test=-34143586739.455) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=2, n_estimators=180;, score=(train=-40015651871.507, test=-112680408386.835) total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=2, n_estimators=180;, score=(train=-41836281693.993, test=-53868723262.983) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=60;, score=(train=-215459512748.670, test=-152771090685.865) total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=60;, score=(train=-221516891587.173, test=-165910091151.819) total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=60;, score=(train=-231586992341.751, test=-141176254266.030) total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=60;, score=(train=-195045723099.698, test=-359457396970.556) total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=60;, score=(train=-197388819333.842, test=-285642419687.132) total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-106591755000.931, test=-60166605939.789) total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-110922906468.812, test=-77049924214.102) total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-114954754098.586, test=-86689475919.858) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-97986750604.384, test=-208083509733.628) total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=(train=-100005473173.513, test=-145542031811.323) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=140;, score=(train=-54171572844.939, test=-25048417003.729) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=140;, score=(train=-57999615466.899, test=-37757100888.274) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=140;, score=(train=-58974234101.301, test=-58457939195.604) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=140;, score=(train=-51492443926.538, test=-128310015888.718) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=140;, score=(train=-52975591553.075, test=-75683240803.394) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=180;, score=(train=-29016273786.879, test=-14505415457.962) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=180;, score=(train=-31875771222.363, test=-20218646610.280) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=180;, score=(train=-31835132589.845, test=-39295906739.273) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=180;, score=(train=-28957831847.285, test=-85864863407.212) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=180;, score=(train=-29730961341.728, test=-37146409252.534) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=4, n_estimators=60;, score=(train=-210689171511.380, test=-145487812632.744) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=4, n_estimators=60;, score=(train=-217011927934.623, test=-163221401896.133) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=4, n_estimators=60;, score=(train=-227100773481.646, test=-143931284862.981) total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=4, n_estimators=60;, score=(train=-189156285566.785, test=-340006216694.704) total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=4, n_estimators=60;, score=(train=-192364364763.460, test=-278184989727.220) total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=-102312513148.301, test=-54623027900.975) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=-106323721148.697, test=-78051363145.085) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=-110556204905.340, test=-82157557989.555) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=-92627483015.678, test=-196157518006.885) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=-94915971190.556, test=-135805079131.333) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=4, n_estimators=140;, score=(train=-51014713895.339, test=-20723952034.626) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=4, n_estimators=140;, score=(train=-53215641008.115, test=-37684116449.839) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=4, n_estimators=140;, score=(train=-54930263723.310, test=-48928196064.052) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=4, n_estimators=140;, score=(train=-46401357933.302, test=-119845818030.001) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=4, n_estimators=140;, score=(train=-47965365674.243, test=-61774733691.601) total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=4, n_estimators=180;, score=(train=-26475272678.354, test=-11682042138.506) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=4, n_estimators=180;, score=(train=-27330767474.629, test=-19394586106.790) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=4, n_estimators=180;, score=(train=-28301357520.092, test=-31297753845.932) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=4, n_estimators=180;, score=(train=-23722159678.967, test=-77771650089.755) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=4, n_estimators=180;, score=(train=-24810619021.878, test=-27764219087.211) total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=60;, score=(train=-210020983727.718, test=-144783400016.533) total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=60;, score=(train=-215627157738.495, test=-154018192245.938) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=60;, score=(train=-226958961548.501, test=-149635379591.376) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=60;, score=(train=-188352657187.717, test=-337672581687.967) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=60;, score=(train=-192125103520.995, test=-277692068317.271) total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-101242699396.721, test=-55153273098.178) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-104698140604.329, test=-68397749870.629) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-109937891517.822, test=-83785628528.691) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-91219351403.673, test=-192893166326.125) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=(train=-94216102671.515, test=-132042110788.258) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=140;, score=(train=-49776469377.671, test=-20890928940.606) total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=140;, score=(train=-51848565180.775, test=-32756763876.560) total time=   0.7s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=140;, score=(train=-54241138448.178, test=-48060335345.769) total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=140;, score=(train=-44812059142.631, test=-115634404841.358) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=140;, score=(train=-46999042083.670, test=-59795888557.932) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=180;, score=(train=-25292672969.295, test=-9615064688.548) total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=180;, score=(train=-26377339986.158, test=-18304716897.452) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=180;, score=(train=-27139287545.427, test=-30024575545.284) total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=180;, score=(train=-22385041987.380, test=-73262103109.998) total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=180;, score=(train=-23903999729.681, test=-26886191506.187) total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=60;, score=(train=-210029784101.923, test=-144169821876.869) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=60;, score=(train=-215611301995.440, test=-153893621094.163) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=60;, score=(train=-226947225146.624, test=-150388065110.063) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=60;, score=(train=-188362816536.720, test=-337810275871.618) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=60;, score=(train=-192167942913.222, test=-278270648826.087) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=-101359772768.350, test=-54065196245.245) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=-104550295091.905, test=-66918969482.478) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=-109874043042.209, test=-85852248842.812) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=-91106302390.382, test=-192433809707.972) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=-94300319847.965, test=-131117650714.188) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=140;, score=(train=-49907604623.474, test=-19609601610.542) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=140;, score=(train=-51607365013.085, test=-31559010208.800) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=140;, score=(train=-53965132424.523, test=-48613718419.588) total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=140;, score=(train=-44475631903.412, test=-115292678348.908) total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=140;, score=(train=-46907241543.909, test=-58148254181.822) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=6, n_estimators=180;, score=(train=-25358632528.220, test=-9353142285.891) total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=6, n_estimators=180;, score=(train=-26107372427.817, test=-16884669308.937) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=6, n_estimators=180;, score=(train=-26996580110.611, test=-30487477582.686) total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=6, n_estimators=180;, score=(train=-22071851407.707, test=-73321905902.452) total time=   0.8s
# [CV 5/5] END learning_rate=0.01, max_depth=6, n_estimators=180;, score=(train=-23705979444.307, test=-25904170753.280) total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=60;, score=(train=-210029784101.923, test=-144169821876.869) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=60;, score=(train=-215611301995.440, test=-153893621094.163) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=60;, score=(train=-226947225146.624, test=-150388065110.063) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=60;, score=(train=-188362816536.720, test=-337810275871.618) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=60;, score=(train=-192167942913.222, test=-278270648826.087) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=(train=-101358871919.819, test=-54219499712.868) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=(train=-104548828154.017, test=-66861492506.992) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=(train=-109869151229.806, test=-85836835113.226) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=(train=-91106302390.382, test=-192433809707.972) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=(train=-94300069871.897, test=-131093787904.087) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=140;, score=(train=-49809446873.660, test=-20698298484.748) total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=140;, score=(train=-51610854856.687, test=-31432553418.154) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=140;, score=(train=-53932292338.604, test=-48470046065.583) total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=140;, score=(train=-44466069400.175, test=-115341070995.668) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=140;, score=(train=-46890470313.875, test=-58146789238.042) total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=180;, score=(train=-25121117971.946, test=-10235150931.807) total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=180;, score=(train=-26035600302.008, test=-16257502829.911) total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=180;, score=(train=-26939597293.535, test=-30204882637.092) total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=180;, score=(train=-22079135991.010, test=-73513074753.747) total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=180;, score=(train=-23659144078.146, test=-25931742714.623) total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=8, n_estimators=60;, score=(train=-210029784101.923, test=-144169821876.869) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=8, n_estimators=60;, score=(train=-215611301995.440, test=-153893621094.163) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=8, n_estimators=60;, score=(train=-226947225146.624, test=-150388065110.063) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=8, n_estimators=60;, score=(train=-188362816536.720, test=-337810275871.618) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=8, n_estimators=60;, score=(train=-192167942913.222, test=-278270648826.087) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=-101358871919.819, test=-54219499712.868) total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=-104548828154.017, test=-66861492506.992) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=-109869151229.806, test=-85836835113.226) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=-91106302390.382, test=-192433809707.972) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=-94300069871.897, test=-131093787904.087) total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=8, n_estimators=140;, score=(train=-49809446873.660, test=-20698298484.748) total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=8, n_estimators=140;, score=(train=-51610854856.687, test=-31432553418.154) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=8, n_estimators=140;, score=(train=-53932292338.604, test=-48470046065.583) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=8, n_estimators=140;, score=(train=-44466069400.175, test=-115341070995.668) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=8, n_estimators=140;, score=(train=-46890470313.875, test=-58146789238.042) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=8, n_estimators=180;, score=(train=-25114352981.380, test=-10239016709.889) total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=8, n_estimators=180;, score=(train=-26041298246.509, test=-16300128073.532) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=8, n_estimators=180;, score=(train=-26939589546.805, test=-30204884033.364) total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=8, n_estimators=180;, score=(train=-22079132711.531, test=-73513080769.065) total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=8, n_estimators=180;, score=(train=-23639379290.462, test=-25904650747.040) total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=60;, score=(train=-210029784101.923, test=-144169821876.869) total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=60;, score=(train=-215611301995.440, test=-153893621094.163) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=60;, score=(train=-226947225146.624, test=-150388065110.063) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=60;, score=(train=-188362816536.720, test=-337810275871.618) total time=   1.4s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=60;, score=(train=-192167942913.222, test=-278270648826.087) total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=(train=-101358871919.819, test=-54219499712.868) total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=(train=-104548828154.017, test=-66861492506.992) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=(train=-109869151229.806, test=-85836835113.226) total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=(train=-91106302390.382, test=-192433809707.972) total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=(train=-94300069871.897, test=-131093787904.087) total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=140;, score=(train=-49809446873.660, test=-20698298484.748) total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=140;, score=(train=-51610854856.687, test=-31432553418.154) total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=140;, score=(train=-53932292338.604, test=-48470046065.583) total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=140;, score=(train=-44466069400.175, test=-115341070995.668) total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=140;, score=(train=-46890470313.875, test=-58146789238.042) total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=9, n_estimators=180;, score=(train=-25114352981.380, test=-10239016709.889) total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=9, n_estimators=180;, score=(train=-26041298246.509, test=-16300128073.532) total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=9, n_estimators=180;, score=(train=-26939589546.805, test=-30204884033.364) total time=   0.8s
# [CV 4/5] END learning_rate=0.01, max_depth=9, n_estimators=180;, score=(train=-22079132711.531, test=-73513080769.065) total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=9, n_estimators=180;, score=(train=-23639379290.462, test=-25904650747.040) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=60;, score=(train=-12242102473.370, test=-21115721974.224) total time=   0.0s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=60;, score=(train=-14440853964.399, test=-11860927001.124) total time=   0.0s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=60;, score=(train=-13223098400.414, test=-22438694724.025) total time=   0.0s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=60;, score=(train=-12690971386.527, test=-50703205258.637) total time=   0.0s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=60;, score=(train=-13913026385.017, test=-12536281271.825) total time=   0.0s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=(train=-4899009185.258, test=-19257786261.542) total time=   0.0s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=(train=-6024410610.660, test=-5475582787.084) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=(train=-5012826389.563, test=-17335919585.713) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=(train=-4713043409.603, test=-24771137174.440) total time=   0.0s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=100;, score=(train=-5342691497.174, test=-7330919401.092) total time=   0.0s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=140;, score=(train=-3697835717.294, test=-19812324062.833) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=140;, score=(train=-4278154343.735, test=-6310138115.817) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=140;, score=(train=-3594799758.774, test=-14904456075.421) total time=   0.0s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=140;, score=(train=-3376030969.741, test=-19309421354.065) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=140;, score=(train=-3592726605.252, test=-9715755878.203) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=2, n_estimators=180;, score=(train=-3093938218.604, test=-19686363456.791) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=2, n_estimators=180;, score=(train=-3459093778.633, test=-7661000390.635) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=2, n_estimators=180;, score=(train=-2870272640.677, test=-14280368510.492) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=2, n_estimators=180;, score=(train=-2844431718.010, test=-16677198767.682) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=2, n_estimators=180;, score=(train=-2882893932.980, test=-11714653511.477) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=60;, score=(train=-7114182219.582, test=-15817513409.783) total time=   0.0s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=60;, score=(train=-7260071046.503, test=-9126959750.458) total time=   0.0s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=60;, score=(train=-6589353399.114, test=-17871303185.225) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=60;, score=(train=-5980547049.233, test=-34832329301.899) total time=   0.0s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=60;, score=(train=-6263589792.757, test=-9242942333.215) total time=   0.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=(train=-2043143325.485, test=-18039256371.064) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=(train=-2395714204.936, test=-12211360233.789) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=(train=-2105915038.228, test=-16418304927.067) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=(train=-1786534419.725, test=-18044378434.501) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=3, n_estimators=100;, score=(train=-1743204141.020, test=-14111070175.780) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=3, n_estimators=140;, score=(train=-1230251506.692, test=-19232530117.636) total time=   0.1s
# ...
# [CV 3/5] END learning_rate=0.05, max_depth=4, n_estimators=140;, score=(train=-402143448.750, test=-12578515426.938) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=4, n_estimators=140;, score=(train=-487003994.523, test=-13596487544.603) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=4, n_estimators=140;, score=(train=-449119222.492, test=-18299053019.397) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=4, n_estimators=180;, score=(train=-267538667.445, test=-19170424424.935) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=4, n_estimators=180;, score=(train=-334379180.771, test=-20118371117.810) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=4, n_estimators=180;, score=(train=-234567395.103, test=-13144873565.255) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=4, n_estimators=180;, score=(train=-314705526.691, test=-13010210180.089) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=4, n_estimators=180;, score=(train=-230675754.242, test=-19610204815.335) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=60;, score=(train=-4366203395.108, test=-11073810312.118) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=60;, score=(train=-4302651315.962, test=-13795003010.472) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=60;, score=(train=-4121116889.169, test=-13892250103.790) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=60;, score=(train=-3424511533.234, test=-27967007059.355) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=60;, score=(train=-3743783237.038, test=-9596880725.439) total time=   0.0s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=(train=-680166683.807, test=-17233853164.913) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=(train=-673263595.245, test=-21696078166.862) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=(train=-614830156.291, test=-11695035258.618) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=(train=-739719146.057, test=-16088874879.211) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=100;, score=(train=-622453999.208, test=-16455275464.383) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=140;, score=(train=-287937689.349, test=-18759172455.365) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=140;, score=(train=-244808073.171, test=-26582297701.409) total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=140;, score=(train=-217310031.148, test=-12106196336.732) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=140;, score=(train=-309379514.075, test=-13193881308.778) total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=140;, score=(train=-228258467.340, test=-19170511483.224) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=5, n_estimators=180;, score=(train=-164797948.891, test=-19354898873.672) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=5, n_estimators=180;, score=(train=-128474061.822, test=-27766187538.716) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=5, n_estimators=180;, score=(train=-104702329.389, test=-12321087573.503) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=5, n_estimators=180;, score=(train=-149733821.695, test=-12523835570.144) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=5, n_estimators=180;, score=(train=-123017778.499, test=-19939046448.313) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=60;, score=(train=-4016363060.240, test=-11170471457.520) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=60;, score=(train=-3924517249.641, test=-14813868177.226) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=60;, score=(train=-3862768092.525, test=-15424584842.171) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=60;, score=(train=-3249896461.388, test=-28097163777.864) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=60;, score=(train=-3491989631.249, test=-9870194229.122) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=(train=-515043176.140, test=-17431480792.593) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=(train=-450600775.343, test=-23095540877.119) total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=(train=-429227420.773, test=-12957432255.077) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=(train=-535739723.778, test=-16313267185.370) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=100;, score=(train=-350520600.044, test=-17097093303.018) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=140;, score=(train=-135155832.900, test=-19563271569.518) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=140;, score=(train=-114139686.236, test=-25611778512.810) total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=140;, score=(train=-103216893.195, test=-12865520683.168) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=140;, score=(train=-192664966.182, test=-13440443917.088) total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=140;, score=(train=-80781082.862, test=-19630956982.400) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=6, n_estimators=180;, score=(train=-58880965.916, test=-20108438009.328) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=6, n_estimators=180;, score=(train=-47994105.880, test=-26237538753.833) total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=6, n_estimators=180;, score=(train=-38109495.349, test=-13038827436.031) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=6, n_estimators=180;, score=(train=-78897372.546, test=-12170783418.810) total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=6, n_estimators=180;, score=(train=-27162219.341, test=-20469065674.795) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=7, n_estimators=60;, score=(train=-3620736099.381, test=-11757610364.634) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=7, n_estimators=60;, score=(train=-3730201538.753, test=-14495421377.051) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=7, n_estimators=60;, score=(train=-3799669170.188, test=-15046363882.979) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=7, n_estimators=60;, score=(train=-3176422870.815, test=-27747011677.756) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=7, n_estimators=60;, score=(train=-3413565672.598, test=-9997325565.612) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-332859689.791, test=-17941490162.725) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-322541865.764, test=-22394765856.086) total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-336153303.646, test=-12390330429.725) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-401946052.244, test=-15441096134.810) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=7, n_estimators=100;, score=(train=-293609476.207, test=-17208925992.322) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=7, n_estimators=140;, score=(train=-62066445.538, test=-19884781814.134) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=7, n_estimators=140;, score=(train=-57450407.712, test=-24878805970.350) total time=   0.2s
# [CV 3/5] END learning_rate=0.05, max_depth=7, n_estimators=140;, score=(train=-60137008.627, test=-12378961483.724) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=7, n_estimators=140;, score=(train=-121389221.585, test=-13478423695.057) total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=7, n_estimators=140;, score=(train=-59862621.199, test=-19739496380.557) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=7, n_estimators=180;, score=(train=-14949422.053, test=-20486331332.797) total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=7, n_estimators=180;, score=(train=-12759519.136, test=-25626666728.810) total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=7, n_estimators=180;, score=(train=-13864619.067, test=-12459809890.440) total time=   0.5s
# [CV 4/5] END learning_rate=0.05, max_depth=7, n_estimators=180;, score=(train=-42500708.651, test=-12814862106.044) total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=7, n_estimators=180;, score=(train=-18680527.264, test=-20543499573.358) total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=60;, score=(train=-3592554601.822, test=-11803717740.114) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=60;, score=(train=-3707275563.286, test=-14953760532.041) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=60;, score=(train=-3766161826.830, test=-14967054802.163) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=60;, score=(train=-3168723997.869, test=-27654745938.655) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=60;, score=(train=-3374419900.523, test=-10011274738.166) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=(train=-296538742.668, test=-17965523893.479) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=(train=-286488259.700, test=-23065711947.060) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=(train=-295317683.728, test=-12249161448.299) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=(train=-344655263.336, test=-14679267178.995) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=100;, score=(train=-268637061.233, test=-17169317301.706) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=140;, score=(train=-39711782.494, test=-19924820090.279) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=140;, score=(train=-38996637.568, test=-25326187439.135) total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=140;, score=(train=-46623858.323, test=-12243545350.119) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=140;, score=(train=-74663898.167, test=-12602491570.372) total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=140;, score=(train=-39844219.144, test=-19823066902.929) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=8, n_estimators=180;, score=(train=-6948477.412, test=-20520116775.588) total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=8, n_estimators=180;, score=(train=-6122347.588, test=-26013637122.389) total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=8, n_estimators=180;, score=(train=-8378997.207, test=-12252674740.549) total time=   0.3s
# [CV 4/5] END learning_rate=0.05, max_depth=8, n_estimators=180;, score=(train=-22638435.936, test=-11967854504.654) total time=   0.3s
# [CV 5/5] END learning_rate=0.05, max_depth=8, n_estimators=180;, score=(train=-8352452.192, test=-20584989733.549) total time=   0.3s
# [CV 1/5] END learning_rate=0.05, max_depth=9, n_estimators=60;, score=(train=-3592104403.400, test=-11932817398.839) total time=   0.1s
# [CV 2/5] END learning_rate=0.05, max_depth=9, n_estimators=60;, score=(train=-3704028204.854, test=-14934981039.428) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=9, n_estimators=60;, score=(train=-3762656099.700, test=-14995672665.693) total time=   0.1s
# [CV 4/5] END learning_rate=0.05, max_depth=9, n_estimators=60;, score=(train=-3164909719.991, test=-27684026595.598) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=9, n_estimators=60;, score=(train=-3358222420.536, test=-10114976735.326) total time=   0.1s
# [CV 1/5] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=(train=-281631773.019, test=-18141686367.639) total time=   0.2s
# [CV 2/5] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=(train=-269030194.164, test=-23027587800.238) total time=   0.1s
# [CV 3/5] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=(train=-280187703.892, test=-12283329846.879) total time=   0.2s
# [CV 4/5] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=(train=-316105410.348, test=-14406264614.861) total time=   0.1s
# [CV 5/5] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=(train=-258092400.749, test=-17173868468.227) total time=   0.2s
# [CV 1/5] END learning_rate=0.05, max_depth=9, n_estimators=140;, score=(train=-33918876.616, test=-20002138381.634) total time=   0.3s
# [CV 2/5] END learning_rate=0.05, max_depth=9, n_estimators=140;, score=(train=-32251626.013, test=-25169789684.952) total time=   0.3s
# [CV 3/5] END learning_rate=0.05, max_depth=9, n_estimators=140;, score=(train=-36028925.477, test=-12251801330.378) total time=   0.3s
# [CV 4/5] END learning_rate=0.05, max_depth=9, n_estimators=140;, score=(train=-45883407.712, test=-11418429173.453) total time=   0.2s
# [CV 5/5] END learning_rate=0.05, max_depth=9, n_estimators=140;, score=(train=-31686576.811, test=-19799094968.182) total time=   0.6s
# [CV 1/5] END learning_rate=0.05, max_depth=9, n_estimators=180;, score=(train=-4587083.741, test=-20557378002.802) total time=   0.4s
# [CV 2/5] END learning_rate=0.05, max_depth=9, n_estimators=180;, score=(train=-4232455.871, test=-25699859581.091) total time=   0.4s
# [CV 3/5] END learning_rate=0.05, max_depth=9, n_estimators=180;, score=(train=-5439982.831, test=-12250340702.061) total time=   0.4s
# [CV 4/5] END learning_rate=0.05, max_depth=9, n_estimators=180;, score=(train=-9576057.935, test=-10980413977.919) total time=   0.4s
# [CV 5/5] END learning_rate=0.05, max_depth=9, n_estimators=180;, score=(train=-4813515.116, test=-20657961905.057) total time=   0.4s
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              param_grid=[{'learning_rate': [0.1, 0.01, 0.05],
#                           'max_depth': range(2, 10),
#                           'n_estimators': range(60, 220, 40)}],
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=3)

# %% [markdown]
# It's a negative mean squared because of scikit-learn's implementation where they decided that higher values are better. These are loss functions so that means lower scores are better. So for it to be good, they flipped the sign for the mse value to be "higher"

# %%
# Best parameter after tuning
print(grid_search.best_params_)

# How our model looks with the best parameters
print(grid_search.best_estimator_)

# Best score after cross validation
neg_mse = grid_search.best_score_
rmse = np.sqrt(-neg_mse)
rmse
# Out:
# {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 180}
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=2, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=180, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)
# 118338.14654377222

# %% [markdown]
# ### 1. Feature Importance and Root Mean Squared Error

# %% [markdown]
# Feature importances now that we have trained our model

# %%
feat_importance = pd.DataFrame(reg.feature_importances_, index=reg.feature_names_in_, columns=['importance'])

# %%
alt.Chart(feat_importance.reset_index().sort_values('importance')).mark_bar().encode(
    x='index',
    y='importance'
)
# Out:
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.Chart(...)

# %% [markdown]
# Predict using the model

# %%
# Predict
reg.predict(X_test)

# Store these predictions
test[['prediction_units', 'prediction_$']] = reg.predict(X_test)

# %% [markdown]
# Compare the predictions with the actuals

# %%
# Merge predictions to the original data to be able to compare and plot it
data_merge = data.merge(test[['prediction_units', 'prediction_$']], how='left', left_index=True, right_index=True).reset_index()

# Plot prediction on line chart 
base = alt.Chart(data_merge[data_merge['Date'] > '2021-12-02']).encode(x=alt.X('Date:O', axis=alt.Axis(labelAngle=-90)))
alt.layer(
    base.mark_line(color='blue', strokeDash=[3,3]).encode(y='prediction_$'),
    base.mark_line(color='blue').encode(y='$'),
    base.mark_line(color='purple', strokeDash=[3,3]).encode(y='prediction_units'),
    base.mark_line(color='purple').encode(y='Units')
).interactive()
# Out:
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.LayerChart(...)

# %% [markdown]
# Root Mean Squared Error

# %%
score_units = np.sqrt(mean_squared_error(test['Units'], test['prediction_units']))
score_rev = np.sqrt(mean_squared_error(test['$'], test['prediction_$']))
print(f'RMSE Score for units on test set: {score_units:0.2f}')
print(f'RMSE Score for revenue on test set: {score_rev:0.2f}')

# Old one before adding in lag and seasons was 
# RMSE Score for units on test set: 71601.73
# RMSE Score for revenue on test set: 230038.59

# Old one with lags shifte by a day
# RMSE Score for units on test set: 47981.77
# RMSE Score for revenue on test set: 146313.01
# Out:
# RMSE Score for units on test set: 68845.22
# RMSE Score for revenue on test set: 209898.85

# %% [markdown]
# Error

# %%
error_rev = pd.DataFrame(abs(test['$'] - test['prediction_$']), columns=['Error']).sort_values(by='Error')
error_units = pd.DataFrame(abs(test['Units'] - test['prediction_units']), columns=['Error']).sort_values(by='Error')

# %%
# First 5 with least error
error_units.head()
# Out:
#                   Error
# Date
# 2021-12-11    60.914469
# 2021-12-25   929.052875
# 2022-01-22  1957.108437
# 2021-12-18  2007.195469
# 2022-01-29  2495.389438

# %%
# First 5 with least error
error_rev.head()
# Out:
#                   Error
# Date
# 2021-12-25   391.024875
# 2021-12-18   460.160250
# 2022-01-01   930.680562
# 2022-05-14  1930.921000
# 2021-12-04  4162.161750

# %% [markdown]
# ### 2. Cross Fold Validation
# - Regular cross fold validation will cause data leakage with time series data. This is because the testing window can be anywhere and the training can be anywhere as well. This can lead to several problems:
#     1. The test data is taking place before the training data
#     2. Data leakage: the training data can take place after the test data, which means the model is able to "peek" into the future
#     3. The training data has gaps because the test data is taken from the middle of the time series
#
# Therefore, we need a method where we can generate folds across a sliding window over time. The length of the training series will grow over time, with each subsequent fold retaining the full series history up to that point. The testing series length for each fold is constant.
#
# ---
# Time Series Cross Validation
# - This is better because it allows you to train your model on past data and evaluate on future data. It is different from other cross-validation techniques, which typically shuffle the data before splitting it into training and test sets, which can lead to **leakage of information** between the training and test sets
# - Make sure to sort your DataFrame first or else it won't work
# - The `TimeSeriesSplit` object is a generator so you have to loop over it and apply it to the training dataset
# - It will return `train_idx` (indices of the dataframe for the training dataset) and `val_idx` (indices of the dataframe for the test dataset)

# %%
# The test_size parameter is how much you want to forecast out. We'll forecast out half a year (the data is in terms of weeks so we'll forecast 26 weeks out)
tss = TimeSeriesSplit(n_splits=5, test_size=26, gap=0)
data = data.sort_index()

# %% [markdown]
# Visualize how the `TimeSeriesSplit` cross validation works

# %%
# sourcery skip: convert-to-enumerate, remove-unused-enumerate
charts = []
fold = 0
for train_idx, val_idx in tss.split(data):
    train = data.iloc[train_idx]
    test = data.iloc[val_idx]
    chart1 = alt.Chart(train.reset_index()).mark_line().encode(x='Date', y='$')
    chart2 = alt.Chart(test.reset_index()).mark_line().encode(x='Date', y='$', color=alt.value("#FFAA00"))

    charts.append(chart1+chart2)
    fold +=1

# * means packaging arguments. In a function call, the * symbol can be used to pass a list of arguments as separate positional arguments
# Also shared the x-axis among all charts
alt.vconcat(*charts).resolve_scale(
    x='shared'
)
# Out:
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %% [markdown]
# Performing `TimeSeriesSplit` cross validation
# - Overfitting means that the `RMSE` is similar in both the test and train datasets

# %%
model = xgb.XGBRegressor(learning_rate=0.05, max_depth=2, n_estimators=180)
rmse = []
plot=[]

for train_idx, val_idx in tss.split(data):
    train = data.iloc[train_idx].copy()
    test = data.iloc[val_idx].copy()

    X_train = train[features]
    y_train = train[target]

    X_test = test[features]
    y_test = test[target]

    # Fit model based on the training dataset
    model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_test, y_test)], verbose=50)

    # Store predictions
    predictions = model.predict(X_test)

    # Root mean squared error
    rmse.append(np.sqrt(np.mean((predictions - y_test) ** 2, axis=0)))
    
    # Merge predictions to the original data to be able to compare and plot it
    test[['prediction_units', 'prediction_$']] = model.predict(X_test)
    data_merge = data.merge(test[['prediction_units', 'prediction_$']], how='left', left_index=True, right_index=True).reset_index()
    # Plot
    base = alt.Chart(data_merge[data_merge['Date'] > '2020-06-13']).encode(x=alt.X('Date')).properties(
    width=800,
    height=300)
    chart = alt.layer(
    base.mark_line(color='blue', strokeDash=[3,3]).encode(y='prediction_$'),
    base.mark_line(color='blue').encode(y='$'),
    base.mark_line(color='purple', strokeDash=[3,3]).encode(y='prediction_units'),
    base.mark_line(color='purple').encode(y='Units')
    )
    plot.append(chart)

alt.vconcat(*plot).resolve_scale(
    x='shared'
)
# Out:
# [0]	validation_0-rmse:716976.29909	validation_1-rmse:895068.68677
# [50]	validation_0-rmse:164785.46006	validation_1-rmse:192581.51458
# [100]	validation_0-rmse:96949.86054	validation_1-rmse:178287.08245
# [150]	validation_0-rmse:77671.55180	validation_1-rmse:185318.19469
# [179]	validation_0-rmse:69542.01072	validation_1-rmse:188458.14997
# [0]	validation_0-rmse:748353.66011	validation_1-rmse:688227.87738
# [50]	validation_0-rmse:168463.85481	validation_1-rmse:98425.33716
# [100]	validation_0-rmse:102742.93551	validation_1-rmse:147912.67901
# [150]	validation_0-rmse:83484.94080	validation_1-rmse:161231.71940
# [179]	validation_0-rmse:76190.56941	validation_1-rmse:161794.90513
# [0]	validation_0-rmse:739949.20958	validation_1-rmse:851592.52828
# [50]	validation_0-rmse:163699.28835	validation_1-rmse:114580.46685
# [100]	validation_0-rmse:103032.22399	validation_1-rmse:120648.28603
# [150]	validation_0-rmse:86911.16346	validation_1-rmse:111583.70286
# [179]	validation_0-rmse:80016.04623	validation_1-rmse:112347.07038
# [0]	validation_0-rmse:754290.70372	validation_1-rmse:669789.80382
# [50]	validation_0-rmse:160446.50864	validation_1-rmse:75278.37008
# [100]	validation_0-rmse:107610.31442	validation_1-rmse:65099.56046
# [150]	validation_0-rmse:90866.84768	validation_1-rmse:68054.29349
# [179]	validation_0-rmse:83657.98671	validation_1-rmse:72613.54009
# [0]	validation_0-rmse:745522.45146	validation_1-rmse:999748.35035
# [50]	validation_0-rmse:156317.06242	validation_1-rmse:245056.93054
# [100]	validation_0-rmse:103259.75418	validation_1-rmse:193539.31371
# [150]	validation_0-rmse:88129.76179	validation_1-rmse:194432.88282
# [179]	validation_0-rmse:81503.15089	validation_1-rmse:195923.93832
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.VConcatChart(...)

# %%
def display_scores(scores):
    print('Scores:', scores)
    print('Mean:', scores.mean())
    print('Standard deviation:', scores.std())

display_scores(np.array(rmse))
# Out:
# Scores: [[ 94190.83536086 249321.15968867]
#  [ 83123.41248566 213179.93017763]
#  [ 55285.7518218  148953.7326268 ]
#  [ 51701.07291542  88726.83655924]
#  [ 83596.10769941 264166.75334569]]
# Mean: 133224.55926811794
# Standard deviation: 76460.36268976625

# %% [markdown]
# ## Predicting
# 1. Create a skeleton frame of dates we want to predict
# 2. Retrain on ALL data (including your test set) because we want to leverage all the data we have to forecast into the future

# %%
X_all = data[features]
y_all = data[target]

reg_final = xgb.XGBRegressor(learning_rate=0.05, max_depth=2, n_estimators=180)

reg_final.fit(X_all, y_all, eval_set=[(X_all, y_all)], verbose=50)
# Out:
# [0]	validation_0-rmse:774094.87428
# [50]	validation_0-rmse:159606.73578
# [100]	validation_0-rmse:110663.11168
# [150]	validation_0-rmse:96930.02555
# [179]	validation_0-rmse:90443.41977
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=2, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=180, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %% [markdown]
# Create the dataframe of future dates

# %%
print('Max date in dataframe: ', data.index.max())
future_df = pd.DataFrame(pd.date_range(start='2022-12-10', end='2023-12-09', freq='7D'))
future_df = future_df.rename(columns={0: 'Date'})

future_df['isFuture'] = True
data['isFuture'] = False

# Make sure the date isn't in the index yet to create the features
data = data.reset_index(drop=False)
data_and_future = pd.concat([data, future_df])

# Create features and lag features in `df_and_future` dataframe
data_and_future = create_features(data_and_future)
data_and_future = lag(data_and_future, 3)
# Out:
# Max date in dataframe:  260

# %%
# Set Date as the index
data_and_future = data_and_future.set_index('Date')
data_and_future.head()
# Out:
#             index          $      Units  month  quarter  year  day_of_year  \
# Date
# 2017-12-09    0.0  72767.839  31271.712     12        4  2017          343
# 2017-12-16    1.0  61041.047  25734.947     12        4  2017          350
# 2017-12-23    2.0  60838.874  25668.437     12        4  2017          357
# 2017-12-30    3.0  51489.301  21898.136     12        4  2017          364
# 2018-01-06    4.0  59647.489  25215.005      1        1  2018            6
#
#             seasons  lag_Units_1  lag_$_1  lag_Units_2  lag_$_2  lag_Units_3  \
# Date
# 2017-12-09        4          NaN      NaN          NaN      NaN          NaN
# 2017-12-16        4          NaN      NaN          NaN      NaN          NaN
# 2017-12-23        4          NaN      NaN          NaN      NaN          NaN
# 2017-12-30        4          NaN      NaN          NaN      NaN          NaN
# 2018-01-06        4          NaN      NaN          NaN      NaN          NaN
#
#             lag_$_3  isFuture
# Date
# 2017-12-09      NaN     False
# 2017-12-16      NaN     False
# 2017-12-23      NaN     False
# 2017-12-30      NaN     False
# 2018-01-06      NaN     False

# %%
future_w_feat = data_and_future.query('isFuture').copy()

# %%
future_w_feat.head()
# Out:
#             index   $  Units  month  quarter  year  day_of_year  seasons  \
# Date
# 2022-12-10    NaN NaN    NaN     12        4  2022          344        4
# 2022-12-17    NaN NaN    NaN     12        4  2022          351        4
# 2022-12-24    NaN NaN    NaN     12        4  2022          358        4
# 2022-12-31    NaN NaN    NaN     12        4  2022          365        4
# 2023-01-07    NaN NaN    NaN      1        1  2023            7        4
#
#             lag_Units_1     lag_$_1  lag_Units_2     lag_$_2  lag_Units_3  \
# Date
# 2022-12-10    47563.316  125240.979    44036.036  116237.727    34704.495
# 2022-12-17    45617.035  121098.254    40208.227  105332.259    32951.272
# 2022-12-24    42322.619  113390.397    34064.763   89222.358    28972.401
# 2022-12-31    39822.238  107773.954    38836.223  101500.678    35420.523
# 2023-01-07    45331.473  123902.778    43628.989  115033.692    32410.422
#
#               lag_$_3  isFuture
# Date
# 2022-12-10  90403.069      True
# 2022-12-17  86408.317      True
# 2022-12-24  76374.202      True
# 2022-12-31  93865.903      True
# 2023-01-07  85832.661      True

# %%
# We only provide it with the features we trained on
future_w_feat[['pred_Units', 'pred_$']] = reg_final.predict(future_w_feat[features])

# %%
plotting_future = future_w_feat.reset_index()
plotting_future = plotting_future.melt(id_vars='Date', value_vars=['pred_Units', 'pred_$'])

plotting_past = data.melt(id_vars='Date', value_vars=['Units', '$'])

(
    alt.Chart(plotting_future).mark_line().encode(
    x='Date',
    y='value',
    color='variable'
)

+

alt.Chart(plotting_past).mark_line().encode(
    x='Date',
    y='value',
    color='variable'
)
)
# Out:
# /home/jacquelinezhangg/anaconda3/envs/ml/lib/python3.10/site-packages/altair/utils/core.py:317: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for col_name, dtype in df.dtypes.iteritems():
# alt.LayerChart(...)

# %% [markdown]
# ## Saving your Model

# %%
import pickle as pl

# %% [markdown]
# Improvement Ideas:
# - Try 2-3 different models
# - Drop rows where there's a null in the lag data? Or does XGBoost just ignore them?
# - Moving average plot: To see what kind of trend a time series might have, we can use a moving average plot. To compute a moving average of a time series, we compute the average of the values within a sliding window of some defined width. Each point on the graph represents the average of all the values in the series that fall within the window on either side. The idea is to smooth out any short-term fluctuations in the series so that only long-term changes remain.
